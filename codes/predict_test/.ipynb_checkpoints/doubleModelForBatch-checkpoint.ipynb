# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import tensorflow as tf
from hanlp.components.pos import RNNPartOfSpeechTagger

tagger1 = RNNPartOfSpeechTagger()
save_moedl='../model/pos1030first/'
tagger1.load(save_moedl)
tagger2 = RNNPartOfSpeechTagger()
save_moedl='../model/pos1030second/'
tagger2.load(save_moedl)
tagger3 = RNNPartOfSpeechTagger()
save_moedl='../model/pos110201/'
tagger3.load(save_moedl)

# %%
def Process(addr, tag):
    strList = []
    tagCur = ''
    for i in range(len(tag)):
        if tag[i] != 'X' and tag[i] != 'M':
            if i != 0:
                strList.append(',')
                strList.append(tagCur)
                strList.append(',')
            strList.append(addr[i])
            tagCur = tag[i]
        else:
            strList.append(addr[i])
    strList.append(',')
    strList.append(tagCur)
    return ''.join(strList)

# %%
def predict(addStr):
    addList = [list(addStr)]
    init = tagger1.predict(addList)[0]
    strNextList = []
    start = -1
    for i in range(len(addList[0])):
        if init[i] == 'RX':
            start = i
            break
    if start == -1:
        return ' '.join(init[:])
    else:
        second = tagger2.predict([addList[0][start:]])[0]
        return ' '.join(init[:start]) + ' ' + ' '.join(second)

# %%
def batchReadFiles(rdAddress):
    with open(rdAddress, 'r') as f:
        for item in f:
            address=list(item[:-1])
            M1 = tagger1.predict(address)
            address1 = Process(address,M1)
            M2 = predict(address)
            M2 = M2.split()
            address2 = Process(address,M2)
            print('原始地址：', item)
            print('一级模型：', address1)
            print('二级模型：', address2)
            M3 = tagger3.predict(address)
            address3 = Process(address,M3)
            print('未分级模型：', address3+'\n')

# %%
batchReadFiles('test4.txt')
# Out:
# 安徽省,R1,六安市,R2,霍邱县,R3,城关地税分局,R4,安徽,R1,六安,R2,霍邱县,R3,城关镇,R4,光明大道,RX
# 安徽省,R1,六安市,R2,霍邱县,R3,城关地税分局,R4,安徽,R1,六安,R2,霍邱县,R3,城关镇,R4,光明大道,R5
# 安徽省,R1,六安市,R2,霍邱县,R3,城关地税分局,R4,安徽,R1,六安,R2,霍邱县,R3,城关镇,R4,光明大道,R5
#
# 北京市,R1,北京市,R1,市辖区,R4,东城区,R4,深圳市,R2,龙岗,R4,坂田,RX,华为基地A10,RX
# 北京市,R1,北京市,R1,市辖区,R4,东城区,R4,深圳市,R2,龙岗,R4,坂田华为基地,R31,A10,R7
# 北京市,R1,北京市,R1,市辖区,R3,东城区,R3,深圳市,R2,龙岗,R4,坂田华为基地,R31,A10,R7
#
# 广东省,R1,佛山市,R2,南海区,R3,广东省,R1,佛山市,R2,南海区,R3,狮山镇,R4,罗村乐安开发区中一,RX
# 广东省,R1,佛山市,R2,南海区,R3,广东省,R1,佛山市,R2,南海区,R3,狮山镇,R4,罗村乐安开发区中一,R5
# 广东省,R1,佛山市,R2,南海区,R3,广东省,R1,佛山市,R2,南海区,R3,狮山镇,R4,罗村乐安开发区中一,R30
#
# 福州,R2,达北农生物技术有限公司,R4,贵州省,R1,贵阳市,R2,黔灵山路T6号金谷苑A3,RX
# 福州,R2,达北农生物技术有限公司,R4,贵州省,R1,贵阳市,R2,黔灵山路,R5,T6号,R6,金谷苑,R30,A3,R7
# 福州,R3,达北农生物技术有限公司,R4,贵州省,R1,贵阳市,R2,黔灵山路,R5,T6号,R6,金谷苑,R30,A3,R7
#
# 甘肃省,R1,酒泉市,R2,玉门市,R3,新市区,R3,老城水管处,R4,甘肃省,R1,疏勒河流勘水资源管理,RX
# 甘肃省,R1,酒泉市,R2,玉门市,R3,新市区,R3,老城水管处,R4,甘肃省,R1,疏勒河流勘水资源管理,R24
# 甘肃省,R1,酒泉市,R2,玉门市,R2,新市区,R3,老城水管处,R4,甘肃省,R1,疏勒河流勘水资源管理,R3
#
# 辽宁省,R1,大连市,R2,理工,R3,大学,R4,07级,R4,辽宁省,R1,大连市,R2,甘井子区凌工路二号北山,R3
# 辽宁省,R1,大连市,R2,理工,R3,大学,R4,07级,R4,辽宁省,R1,大连市,R2,甘井子区凌工路二号北山,R3
# 辽宁省,R1,大连市,R2,理工,R4,大学07级,R4,辽宁省,R1,大连市,R2,甘井子区,R3,凌工路,R5,二号北山,R6
#
# 广东省,R1,深圳市,R2,宝安区,R3,深圳市,R2,宝安区,R3,西乡固戍愉盛工业园金环怡比亚,R4
# 广东省,R1,深圳市,R2,宝安区,R3,深圳市,R2,宝安区,R3,西乡固戍愉盛工业园金环怡比亚,R4
# 广东省,R1,深圳市,R2,宝安区,R3,深圳市,R2,宝安区,R3,西乡,R4,固戍愉盛工业园金环怡比亚,R30
#
# 山东省,R1,烟台市,R2,莱山区,R3,观海路３４６号成教学楼４０１宿舍滨州医学院,RX
# 山东省,R1,烟台市,R2,莱山区,R3,观海路,R5,３４６号成教学楼４０１宿舍,R30,滨州医学院,R21
# 山东省,R1,烟台市,R2,莱山区,R3,观海路,R5,３４６号成教学楼４０１宿舍滨州医学院,R90
#
# 贵州省,R1,遵义市,R2,遵义县,R3,医学院职工集体宿舍免疫学教研室,RX
# 贵州省,R1,遵义市,R2,遵义县,R3,医学院职工集体宿舍,R30,免疫学教研室,R21
# 贵州省,R1,遵义市,R2,遵义县医学院职工集体宿舍免疫学教研室,R20
#
# 宿州市公安局桥区,R2,分局,R4,桃园,R4,派出所,R4,安徽省,R1,宿州市,R2,?桥区,R3,宿怀路42,RX
# 宿州市公安局桥区,R2,分局,R4,桃园,R4,派出所,R4,安徽省,R1,宿州市,R2,?桥区,R3,宿怀路,R5,42,R6
# 宿州市,R2,公安局桥区,R4,分局桃园派出所,R4,安徽省,R1,宿州市,R2,?桥区,R3,宿怀路,R5,42,R6
#
# 新疆维吾尔自治区,R1,克拉玛依市,R2,康城,R3,花园,R4,吉祥路63排110栋11号,RX
# 新疆维吾尔自治区,R1,克拉玛依市,R2,康城,R3,花园,R4,吉祥路,R5,63排,R6,110栋,R6,11号,R7
# 新疆维吾尔自治区,R1,克拉玛依市,R2,康城,R3,花园,R4,吉祥路,R5,63排,R6,110栋,R6,11号,R7
#
# 河南省,R1,信阳市,R2,河区,R3,河南省,R1,信阳市农行中山北路分理处205号,RX
# 河南省,R1,信阳市,R2,河区,R3,河南省,R1,信阳市农行中山北路分理处,R23,205号,R6
# 河南省,R1,信阳市,R2,河区,R3,河南省,R1,信阳市农行中山北路分理处,R24,205号,R6
#
# 中国,R4,山东省,R1,临沂市,R2,沂南县,R3,振兴路南村村委办公大楼广汇集团,RX
# 中国,R4,山东省,R1,临沂市,R2,沂南县,R3,振兴路,R5,南村村委办公大楼,R31,广汇集团,R20
# 中国,R4,山东省,R1,临沂市,R2,沂南县,R3,振兴路南村村委办公大楼广汇集团,R4
#
# 重庆,R1,展锋物业管理有限公司,R4,重庆市,R1,沙坪坝区,R3,小龙坎正街336号,RX
# 重庆,R1,展锋物业管理有限公司,R4,重庆市,R1,沙坪坝区,R3,小龙坎正街,R5,336号,R6
# 重庆,R1,展锋物业管理有限公司,R4,重庆市,R1,沙坪坝区,R3,小龙坎正街,R5,336号,R6
#
# 贵州省,R1,遵义市,R2,习水区,R3,大陆村仁爱医院对面环城路1号,RX
# 贵州省,R1,遵义市,R2,习水区,R3,大陆村仁爱医院,R22,对面,R90,环城路,R5,1号,R6
# 贵州省,R1,遵义市,R2,习水区,R3,大陆村仁爱医院,R22,对面,R90,环城路,R5,1号,R6
#
# 天津,R1,天津,R1,天津市,R1,宝坻区,R3,步行街福润德珠宝,RX
# 天津,R1,天津,R1,天津市,R1,宝坻区,R3,步行街,R5,福润德珠宝,R25
# 天津,R1,天津,R1,天津市,R1,宝坻区,R3,步行街福润德珠宝,R5
#
# 山东省,R1,临沂市,R2,山东省,R1,临沂市,R2,罗庄区,R3,湖北路黄对河工业园临沂俊发建,RX
# 山东省,R1,临沂市,R2,山东省,R1,临沂市,R2,罗庄区,R3,湖北路,R5,黄对河工业园,R31,临沂俊发建,R25
# 山东省,R1,临沂市,R2,山东省,R1,临沂市,R2,罗庄区,R3,湖北路,R5,黄对河工业园临沂俊发建,R90
#
# 山东省,R1,淄博市,R2,周村区,R3,新建中路75号淄博市中医医院儿科淄博市中医医,RX
# 山东省,R1,淄博市,R2,周村区,R3,新建中路,R5,75号,R6,淄博市中医医院儿科淄博市中医医,R22
# 山东省,R1,淄博市,R2,周村区,R3,新,R5,建中路,R5,75号,R6,淄博市中医医院儿科淄博市中医医,R21
#
# 山东,R4,潍坊,R2,山东省,R1,潍坊市,R2,潍城区,R3,东风西街豪德广场农行豪杰机床城,RX
# 山东,R4,潍坊,R2,山东省,R1,潍坊市,R2,潍城区,R3,东风西街,R5,豪德广场农行豪杰机床城,R31
# 山东,R4,潍坊,R2,山东省,R1,潍坊市,R2,潍城区,R3,东风西街,R5,豪德广场农行豪杰机床城,R31
#
# 北京市,R1,朝阳区,R3,京顺路香江北路１号北京香江花园俱乐部北京香江花园,RX
# 北京市,R1,朝阳区,R3,京顺路,R5,香江北路,R5,１号北京香江花园俱乐部,R25,北京香江花园,R30
# 北京市,R1,朝阳区,R3,京顺路,R5,香江北路,R5,１号北京香江花园俱乐部,R25,北京香江花园,R90
#
# 安徽省,R1,阜阳市,R2,界首市,R3,东城区,R3,人民路工业园区安徽福斯特渔具有限公司,RX
# 安徽省,R1,阜阳市,R2,界首市,R3,东城区,R3,人民路,R5,工业园区,R31,安徽福斯特渔具有限公司,R20
# 安徽省,R1,阜阳市,R2,界首市,R3,东城区,R5,人民路,R5,工业园区安徽福斯特渔具有限公司,R20
#
# 广西壮族自治区,R1,贺州市,R2,昭平县,R3,黄姚镇,R4,广西昭平县,R1,黄姚镇,R4,巩桥中学行,RX
# 广西壮族自治区,R1,贺州市,R2,昭平县,R3,黄姚镇,R4,广西昭平县,R1,黄姚镇,R4,巩桥中学行,R21
# 广西壮族自治区,R1,贺州市,R2,昭平县,R3,黄姚镇,R4,广西,R1,昭平县,R3,黄姚镇巩桥中学行,R21
#
# 北京市,R1,北京市,R1,丰台区,R3,西南四环188号18区3号楼邮储银行,RX
# 北京市,R1,北京市,R1,丰台区,R3,西南四环,R5,188号,R6,18区,R6,3号楼,R6,邮储银行,R23
# 北京市,R1,北京市,R1,丰台区,R3,西南四环,R90,188号,R6,18区,R6,3号楼邮储银行,R7
#
# 天津,R1,天津,R1,天津市,R1,西青区,R3,外环线9号桥兴达货运中心后院C区10号,RX
# 天津,R1,天津,R1,天津市,R1,西青区,R3,外环线,R5,9号,R6,桥兴达货运中心,R31,后院,R6,C区,R6,10号,R7
# 天津,R1,天津,R1,天津市,R3,西青区,R3,外环线,R5,9号桥兴达货运中心,R6,后院,R90,C区,R6,10号,R7
#
# 安徽省,R1,宿州市,R2,桥区,R3,二冬大道宿州学院东区行政楼A栋203室宿州学院,RX
# 安徽省,R1,宿州市,R2,桥区,R3,二冬大道,R5,宿州学院东区行政楼,R21,A栋,R6,203室,R7,宿州学院,R21
# 安徽省,R1,宿州市,R2,桥区,R3,二冬大道宿州学院东区行政楼,R5,A栋,R6,203室,R7,宿州学院,R21
#
# 云南省,R1,普洱市,R2,澜沧区,R3,民族街华隆小区三组团彭朝明家租房,RX
# 云南省,R1,普洱市,R2,澜沧区,R3,民族街,R5,华隆小区,R30,三组团,R30,彭朝明家租房,R30
# 云南省,R1,普洱市,R2,澜沧区,R3,民族街,R5,华隆小区三组团彭朝明家租房,R30
#
# 安徽,R1,池州市,R2,池州市,R2,贵池区,RX,龙登凤凰城门面,RX
# 安徽,R1,池州市,R2,池州市,R2,贵池区龙登凤凰城,R30,门面,R90
# 安徽,R1,池州市,R2,池州市,R2,贵池区龙登凤凰城门面,R30
#
# 安徽省,R1,宿州市,R2,第七建筑安装工程有限公司,R4,安徽省,R1,宿州市,R2,宿怀路264,RX
# 安徽省,R1,宿州市,R2,第七建筑安装工程有限公司,R4,安徽省,R1,宿州市,R2,宿怀路,R5,264,R6
# 安徽省,R1,宿州市,R2,第七建筑安装工程有限公司,R4,安徽省,R1,宿州市,R2,宿怀路,R5,264,R6
#
# 广东省,R1,深圳市,R2,深圳市,RX,宝安49区华创达文化广场C301三好智能深圳,RX
# 广东省,R1,深圳市,R2,深圳市宝安,R31,49区,R6,华创达文化广场,R31,C301,R7,三好智能深圳,R31
# 广东省,R1,深圳市,R2,深圳市,R2,宝安,R3,49区华创达文化广场,R6,C301三好智能深圳,R7
#
# 山东,R1,滨州,R2,山东省,R1,滨州市,R2,滨城区,R3,滨北办事处张富路288号,RX
# 山东,R1,滨州,R2,山东省,R1,滨州市,R2,滨城区,R3,滨北办事处,R24,张富路,R5,288号,R6
# 山东,R1,滨州,R2,山东省,R1,滨州市,R2,滨城区,R3,滨北办事处,R24,张富路,R5,288号,R6
#
# 广西壮族自治区,R1,贵港市,R2,广西,R1,贵港市,R2,港南区,R3,江南工业园A区工业一路贵,RX
# 广西壮族自治区,R1,贵港市,R2,广西,R1,贵港市,R2,港南区,R3,江南工业园,R31,A区,R6,工业一路贵,R5
# 广西壮族自治区,R1,贵港市,R2,广西,R4,贵港市,R2,港南区,R3,江南工业园,R4,A区工业一路,R6,贵,R90
#
# 亿科通讯,R4,安徽省,R1,合肥市,R2,瑶海区,R3,火车站对面白马万商一楼中国联通,RX
# 亿科通讯,R4,安徽省,R1,合肥市,R2,瑶海区,R3,火车站对面,R25,白马万商,R31,一楼,R7,中国联通,R25
# 亿科,R4,通讯,R4,安徽省,R1,合肥市,R2,瑶海区,R3,火车站,R5,对面,R90,白马万商一楼中国联通,R31
#
# 广东省,R1,佛山市,R2,顺德区,R3,碧桂花城翠湖畔一区三街2栋108房,RX
# 广东省,R1,佛山市,R2,顺德区,R3,碧桂花城,R5,翠湖畔一区,R5,三街,R5,2栋,R6,108房,R7
# 广东省,R1,佛山市,R2,顺德区,R3,碧桂花城翠湖畔一区三街,R4,2栋,R6,108房,R7
#
# 陕西省,R1,榆林市,R2,榆阳区,R3,榆阳区创业大厦卵化孵化,RX
# 陕西省,R1,榆林市,R2,榆阳区,R3,榆阳区创业大厦卵化孵化,R31
# 陕西省,R1,榆林市,R2,榆阳区,R3,榆阳区创业大厦卵化孵化,R31
#
# 广东省,R1,东莞市,R2,长安镇,R4,乌沙步步高大道东莞市长安镇新民边防派,RX
# 广东省,R1,东莞市,R2,长安镇,R4,乌沙步步高大道,R5,东莞市长安镇新民边防派,R24
# 广东省,R1,东莞市,R2,长安镇,R4,乌沙步步,R5,高大道,R4,东莞市,R2,长安镇新民边防派,R4
#
# 自营,R2,货车,R4,运营,R2,陕西省,R1,子洲县,R3,苗家坪镇,R4,杜家沟村1-6-6026108,RX
# 自营,R2,货车,R4,运营,R2,陕西省,R1,子洲县,R3,苗家坪镇,R4,杜家沟村1-6-6026108,R5
# 自营货车,R2,运营,R2,陕西省,R1,子洲县,R3,苗家坪镇,R4,杜家沟村,R5,1-6-6026108,R6
#
# 江苏省,R1,无锡市,R2,宜兴市,R3,太涌东路39号欧派电动车宜兴市宜城街道嘉宾电,RX
# 江苏省,R1,无锡市,R2,宜兴市,R3,太涌东路,R5,39号,R6,欧派电动车,R25,宜兴市,R25,宜城街道嘉宾电,R25
# 江苏省,R1,无锡市,R2,宜兴市,R3,太,R5,涌东路,R5,39号,R6,欧派电动车宜兴市,R25,宜城街道嘉宾电,R25
#
# 广东,R1,肇庆,R2,四会市,RX,农业银行西会市支行大中酒店首层,RX
# 广东,R1,肇庆,R2,四会市农业银行西会市支行,R25,大中酒店,R25,首层,R7
# 广东,R1,肇庆,R2,四会市农业银行西会市支行,R23,大中酒店,R25,首层,R7
#
# 杭州意法服饰城张金苗服饰店,RX
# 杭州意法服饰城,R25,张金苗服饰店,R25
# 杭州意法服饰城张金苗服饰店,R25
#
# 浙江省,R1,台州市,R2,天台县,R3,浙江省,R1,天台县,R3,白鹤镇,R4,西工业园区东园路5号永贵,RX
# 浙江省,R1,台州市,R2,天台县,R3,浙江省,R1,天台县,R3,白鹤镇,R4,西工业园区,R31,东园路,R5,5号,R6,永贵,R21
# 浙江省,R1,台州市,R2,天台县,R3,浙江省,R1,天台县,R3,白鹤镇,R4,西工业园区东园路,R30,5号永贵,R6
#
# 甘肃省,R1,嘉峪关市,R2,长城区,R3,建设社区服务中心长城区建设社区,RX
# 甘肃省,R1,嘉峪关市,R2,长城区,R3,建设社区,R5,服务中心,R31,长城区建设社区,R5
# 甘肃省,R1,嘉峪关市,R2,长城区,R24,建设社区服务中心,R4,长城区,R3,建设社区,R5
#
# 界首市,R3,双马机械有限公司,R4,安徽省,R1,界首市,R3,鸭王工业园区中心路室,RX
# 界首市,R3,双马机械有限公司,R4,安徽省,R1,界首市,R3,鸭王工业园区,R31,中心路,R5,室,R90
# 界首市,R3,双马机械有限公司,R4,安徽省,R1,界首市,R3,鸭王工业园区,R31,中心路,R5,室,R90
#
# 江西省,R1,吉安市,R2,峡江县,R3,东鹏瓷,R4,砖店,R4,江西省,R1,吉安市,R2,峡江县,R3,水边镇,R4,玉峡大,RX
# 江西省,R1,吉安市,R2,峡江县,R3,东鹏瓷,R4,砖店,R4,江西省,R1,吉安市,R2,峡江县,R3,水边镇,R4,玉峡大,R5
# 江西省,R1,吉安市,R2,峡江县,R3,东鹏瓷,R4,砖店,R4,江西省,R1,吉安市,R2,峡江县,R3,水边镇,R4,玉峡大,R5
#
# 江苏省,R1,淮安市,R2,淮阴,R3,工学院枚乘路校区淮阴工学院,RX
# 江苏省,R1,淮安市,R2,淮阴,R3,工学院枚乘路,R21,校区,R21,淮阴工学院,R21
# 江苏省,R1,淮安市,R2,淮阴,R3,工学院,R5,枚乘路,R5,校区,R90,淮阴工学院,R21
#
# 山东,R1,临沂,R2,临沂市,R2,兰山区,R3,金锣科技园姚店子苗庄养殖场,RX
# 山东,R1,临沂,R2,临沂市,R2,兰山区,R3,金锣科技园,R31,姚店子苗庄养殖场,R20
# 山东,R1,临沂,R2,临沂市,R2,兰山区,R31,金锣科技园,R4,姚店子苗庄养殖场,R20
#
# 浙江省,R1,台州市,R2,浙江省,R1,台州市,R2,临海市,R3,上盘镇,R4,北洋工业园区北洋十一路,RX
# 浙江省,R1,台州市,R2,浙江省,R1,台州市,R2,临海市,R3,上盘镇,R4,北洋工业园区,R31,北洋十一路,R5
# 浙江省,R1,台州市,R2,浙江省,R1,台州市,R2,临海市,R3,上盘镇,R4,北洋工业园区北洋十一路,R30
#
# 山东省,R1,济宁市,R2,金乡县,R3,胡集镇,R4,工业园区亿盛实业有限公司山东亿盛实业,RX
# 山东省,R1,济宁市,R2,金乡县,R3,胡集镇,R4,工业园区亿盛实业有限公司山东亿盛实业,R20
# 山东省,R1,济宁市,R2,金乡县,R3,胡集镇,R4,工业园区亿盛实业有限公司,R20,山东亿盛实业,R90
#
# 上海,R1,建工集团基础工程公司,R4,上海市,R1,江西中路406号,RX
# 上海,R1,建工集团基础工程公司,R4,上海市,R1,江西中路,R5,406号,R6
# 上海,R1,建工集团基础工程公司,R4,上海市,R1,江西中路,R5,406号,R6
#
# 天津市县宁河县,R1,天津,R1,天津,R1,宁河区宁河,R3,镇,RX,四村村委会,RX
# 天津市县宁河县,R1,天津,R1,天津,R1,宁河区宁河,R3,镇四村村委会,R24
# 天津市县,R3,宁河县,R3,天津,R1,天津,R1,宁河区,R3,宁河镇,R4,四村村委会,R24
#
# 河北省,R1,张家口市,R2,张家口市高新技术产业开发区,R3,蔚县交警队胜利东路58,RX
# 河北省,R1,张家口市,R2,张家口市高新技术产业开发区,R3,蔚县交警队,R24,胜利东路,R5,58,R6
# 河北省,R1,张家口市,R2,张家口市高新技术产业开发区,R3,蔚县交警队,R4,胜利东路,R5,58,R6
#
# 五河县,R3,鑫龙汽车运输有限公司,R4,安徽省,R1,蚌埠市,R2,五河县,R3,城关镇闸桥路,R4
# 五河县,R3,鑫龙汽车运输有限公司,R4,安徽省,R1,蚌埠市,R2,五河县,R3,城关镇闸桥路,R4
# 五河县,R3,鑫龙汽车运输有限公司,R4,安徽省,R1,蚌埠市,R2,五河县,R3,城关镇,R4,闸桥路,R5
#
# 江苏省,R1,苏州市,R2,苏州市,R2,相城区,R3,相城大道蠡口国际家具城汇海龙C0,RX
# 江苏省,R1,苏州市,R2,苏州市,R2,相城区,R3,相城大道,R5,蠡口国际家具城汇海龙,R31,C0,R7
# 江苏省,R1,苏州市,R2,苏州市,R2,相城区,R3,相城大道,R5,蠡口国际家具城汇海龙C0,R31
# 北京,R1,北京,R1,北京市,R1,通州区,R3,新华大街171号怡佳家园群楼世纪联华,RX
# 北京,R1,北京,R1,北京市,R1,通州区,R3,新华大街,R5,171号,R6,怡佳家园群楼世纪联华,R30
# 北京,R1,北京,R2,北京市,R1,通州区,R3,新华大街,R5,171号,R6,怡佳家园群楼世纪联华,R30
#
# 广东省,R1,佛山市,R2,顺德区,R3,顺德区,R3,龙江镇,R4,龙江社区居民委员会北华路,RX
# 广东省,R1,佛山市,R2,顺德区,R3,顺德区,R3,龙江镇,R4,龙江社区居民委员会,R24,北华路,R5
# 广东省,R1,佛山市,R2,顺德区,R3,顺德区,R3,龙江镇,R4,龙江社区居民委员会,R24,北华路,R5
#
# 重庆,R1,金凯农业发展有限公司,R4,重庆市,R1,渝北区,R3,东湖南路333号中渝爱都会,RX
# 重庆,R1,金凯农业发展有限公司,R4,重庆市,R1,渝北区,R3,东湖南路,R5,333号,R6,中渝爱都会,R31
# 重庆,R20,金凯农业发展有限公司,R4,重庆市,R1,渝北区,R3,东湖南路,R5,333号,R6,中渝爱都会,R31
#
# 山东省,R1,枣庄市,R2,薛城区,R3,枣庄市,R2,薛城区安桥国际A座8楼枣庄大成煤业有限,R3
# 山东省,R1,枣庄市,R2,薛城区,R3,枣庄市,R2,薛城区安桥国际A座8楼枣庄大成煤业有限,R3
# 山东省,R1,枣庄市,R2,薛城区,R3,枣庄市,R31,薛城区,R4,安桥国际,R31,A座,R6,8楼,R7,枣庄大成煤业有限,R20
#
# 河北,R4,衡水,R4,河北省,R1,衡水市,R2,武邑县,R3,城花园路宏达小区,RX
# 河北,R4,衡水,R4,河北省,R1,衡水市,R2,武邑县,R3,城花园路,R5,宏达小区,R30
# 河北,R4,衡水,R4,河北省,R1,衡水市,R2,武邑县,R3,城花园路,R5,宏达小区,R30
#
# 河北,R1,承德,R2,围场县,R3,腰站乡卫生院,R4,围场县腰站乡腰站村,R3
# 河北,R1,承德,R2,围场县,R3,腰站乡卫生院,R4,围场县腰站乡腰站村,R3
# 河北,R1,承德,R2,围场县,R3,腰站乡,R4,卫生院,R3,围场县,R3,腰站乡,R4,腰站村,R5
#
# 广东省,R1,广州市,R2,增城,R3,荔城街华南路1号S4南429广东商学院华商,RX
# 广东省,R1,广州市,R2,增城,R3,荔城街,R5,华南路,R5,1号,R6,S4南429,R7,广东商学院华商,R21
# 广东省,R1,广州市,R2,增城,R3,荔城街,R5,华南路,R5,1号S4南429广东商学院华商,R6
#
# 广东省,R1,深圳市,R2,福田区,R3,广东省,R1,深圳市,R2,福田区,R3,车公庙,R4,泰然九路1号盛唐大,RX
# 广东省,R1,深圳市,R2,福田区,R3,广东省,R1,深圳市,R2,福田区,R3,车公庙,R4,泰然九路,R5,1号,R6,盛唐大,R31
# 广东省,R1,深圳市,R2,福田区,R3,广东省,R1,深圳市,R2,福田区,R3,车公庙,R4,泰然九路,R5,1号盛唐大,R6
#
# 河北省,R1,邢台市,R2,柏乡县,R3,固城店镇,R4,高宁路2号柏乡县固城店镇人民政府,RX
# 河北省,R1,邢台市,R2,柏乡县,R3,固城店镇,R4,高宁路,R5,2号,R6,柏乡县固城店镇人民政府,R24
# 河北省,R1,邢台市,R2,柏乡县,R3,固城店镇,R4,高宁路,R5,2号,R6,柏乡县固城店镇人民政府,R30
#
# 北京市,R1,大兴区,R3,经济技术开发区,R4,康定街18号永康公寓全季酒店,RX
# 北京市,R1,大兴区,R3,经济技术开发区,R4,康定街,R5,18号,R6,永康公寓,R30,全季酒店,R25
# 北京市,R1,大兴区,R3,经济技术开发区,R4,康定街,R5,18号,R6,永康公寓全季酒店,R25
#
# 安徽省,R1,宿州市,R2,桥区,R3,城东办事处桥区农机安全监理站,RX
# 安徽省,R1,宿州市,R2,桥区,R3,城东办事处,R24,桥区农机安全监理站,R20
# 安徽省,R1,宿州市,R2,桥区,R3,城东办事处,R24,桥区农机安全监理站,R24
#
# 四川省,R1,凉山自治州,R2,雷波区,R3,锦城镇,R4,新街地税局,RX
# 四川省,R1,凉山自治州,R2,雷波区,R3,锦城镇,R4,新街地税局,R24
# 四川省,R1,凉山自治州,R2,雷波区,R3,锦城镇,R4,新街地税局,R24
#
# 云南省,R1,普洱市,R2,澜沧拉祜族自治县,R3,水库东路经作中心澜沧县经济作物技,RX
# 云南省,R1,普洱市,R2,澜沧拉祜族自治县,R3,水库东路,R5,经作中心,R31,澜沧县经济作物技,R31
# 云南省,R1,普洱市,R2,澜沧拉祜族自治县,R3,水库东路,R5,经作中心,R90,澜沧县经济作物技,R31
#
# 贵州省,R1,六盘水市,R2,六枝特区,R3,那平路公安局,RX
# 贵州省,R1,六盘水市,R2,六枝特区,R3,那平路,R5,公安局,R24
# 贵州省,R1,六盘水市,R2,六枝特区,R3,那平路公安局,R24
#
# 吉安市,R2,吉州区,R3,江村镇,R4,银行金融业务中心江西省吉安市阳明西路33号,R4
# 吉安市,R2,吉州区,R3,江村镇,R4,银行金融业务中心江西省吉安市阳明西路33号,R4
# 吉安市,R2,吉州区,R3,江村镇,R4,银行金融业务中心,R4,江西省,R1,吉安市,R2,阳明西路,R5,33号,R6
#
# 吉林省,R1,吉林市,R2,船营区,R3,吉林市农行西胜支行北京路180号,RX
# 吉林省,R1,吉林市,R2,船营区,R3,吉林市农行西胜支行,R23,北京路,R5,180号,R6
# 吉林省,R1,吉林市,R2,船营区,R3,吉林市农行西胜支行,R23,北京路,R5,180号,R6
#
# 浙江省,R1,绍兴市,R2,越城区,R3,绍兴市,R2,城南,R4,九里市劳教所旁,RX
# 浙江省,R1,绍兴市,R2,越城区,R3,绍兴市,R2,城南,R4,九里市劳教所,R24,旁,R90
# 浙江省,R1,绍兴市,R2,越城区,R3,绍兴市,R2,城南九里市劳教所,R4,旁,R90
#
# 江西,R1,赣州,R2,上犹县,R3,上犹县,R3,备田,R4,桂花园市场2号店,RX
# 江西,R1,赣州,R2,上犹县,R3,上犹县,R3,备田,R4,桂花园市场,R31,2号店,R7
# 江西,R1,赣州,R2,上犹县,R3,上犹县,R3,备田,R4,桂花园市场2号店,R25
#
# 佛山市,R2,顺德区,R3,伦教街道办事处常教居委会北海先锋路20号,RX
# 佛山市,R2,顺德区,R3,伦教街道办事处,R24,常教居委会,R24,北海先锋路,R5,20号,R6
# 佛山市,R2,顺德区,R3,伦教街道办事处,R24,常教居委会,R24,北海先锋路,R30,20号,R6
#
# 浙江,R1,温州,R2,浙江省,R1,温州市屿田段座北已详,RX
# 浙江,R1,温州,R2,浙江省,R1,温州市屿田段座,R31,北已详,R90
# 浙江,R1,温州,R2,浙江省,R1,温州市屿田段座,R2,北已详,R90
#
# 上海市,R1,上海市,R1,上海市,R1,上海市,R1,嘉定区,R3,嘉定工业区,RX,金兰路333号,RX
# 上海市,R1,上海市,R1,上海市,R1,上海市,R1,嘉定区,R3,嘉定工业区,R31,金兰路,R5,333号,R6
# 上海市,R1,上海市,R1,上海市,R1,上海市,R1,嘉定区,R3,嘉定工业区,R30,金兰路,R5,333号,R6
#
# 河北省,R1,石家庄市,R2,待客,R4,户领卡时补充,R4,河北省,R1,石家庄市,R2,桥西区,R3,南三,R4
# 河北省,R1,石家庄市,R2,待客,R4,户领卡时补充,R4,河北省,R1,石家庄市,R2,桥西区,R3,南三,R4
# 河北省,R1,石家庄市,R2,待客,R4,户领卡时补充,R4,河北省,R1,石家庄市,R2,桥西区,R3,南三,R90
#
# 北京市,R1,北京市,R1,通州区,R3,车站路9号院里二层211-212室,RX
# 北京市,R1,北京市,R1,通州区,R3,车站路,R30,9号院里二层,R6,211-212室,R7
# 北京市,R1,北京市,R1,通州区,R3,车站路9号院里,R5,二层,R7,211-212室,R7
#
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学无为县刘渡初级中学,RX
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学,R21,无为县刘渡初级中学,R21
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学无为县刘渡初级中学,R5
#
# 广东,R1,茂名,R2,广东省,R1,茂名市高新技术产业开发区,R2,食品包装工业加工区,RX
# 广东,R1,茂名,R2,广东省,R1,茂名市高新技术产业开发区,R2,食品包装工业加工区,R31
# 广东,R1,茂名,R2,广东省,R1,茂名市高新技术产业开发区食品包装工业加工区,R31
#
# 安徽省,R1,合肥市,R2,合肥市,RX,文达信息工程学院商业楼一号楼,RX
# 安徽省,R1,合肥市,R2,合肥市文达信息工程学院商业楼,R31,一号楼,R6
# 安徽省,R1,合肥市,R2,合肥市,R2,文达信息工程学院商业楼,R31,一号楼,R6
#
# 曹县,R3,青集镇,R4,家家乐超市,R2,山东省曹县青集镇刘寨行政村刘寨村325,R1
# 曹县,R3,青集镇,R4,家家乐超市,R2,山东省曹县青集镇刘寨行政村刘寨村325,R1
# 曹县,R3,青集镇,R4,家家乐超市,R4,山东省,R1,曹县,R3,青集镇,R4,刘寨行政村刘寨村,R30,325,R7
#
# 中国,R3,黑龙江,R1,齐齐哈尔,R2,富拉尔基,R3,黑龙江省,R1,齐齐哈尔市,R2,富拉尔基重机厂,RX
# 中国,R3,黑龙江,R1,齐齐哈尔,R2,富拉尔基,R3,黑龙江省,R1,齐齐哈尔市,R2,富拉尔基重机厂,R20
# 中国,R4,黑龙江,R1,齐齐哈尔,R2,富拉尔基,R3,黑龙江省,R1,齐齐哈尔市,R2,富拉尔基重机厂,R20
#
# 广东省,R1,佛山市,R2,佛山市,R2,顺德区,RX,大良趣步户外有限,RX
# 广东省,R1,佛山市,R2,佛山市,R2,顺德区大良趣步户外有限,R20
# 广东省,R1,佛山市,R2,佛山市,R2,顺德区,R3,大良趣步户外有限,R20
#
# 河南,R1,郑州,R2,中原区,R3,河南省,R1,扶沟县,R3,园区2号路河南省扶沟县职业教育中心,RX
# 河南,R1,郑州,R2,中原区,R3,河南省,R1,扶沟县,R3,园区,R5,2号路,R6,河南省扶沟县职业教育中心,R20
# 河南,R1,郑州,R2,中原区,R3,河南省,R1,扶沟县,R3,园区,R4,2号路,R5,河南省,R1,扶沟县职业教育中心,R21
#
# 河南省,R1,洛阳市,R2,伊川县,R3,洛阳市,R2,伊川县,R3,华美建材城b区13号楼二楼,RX
# 河南省,R1,洛阳市,R2,伊川县,R3,洛阳市,R2,伊川县,R3,华美建材城,R25,b区,R6,13号楼,R6,二楼,R7
# 河南省,R1,洛阳市,R2,伊川县,R3,洛阳市,R2,伊川县,R3,华美建材城,R25,b区,R6,13号楼,R6,二楼,R7
#
# 浙江,R1,杭州,R2,浙江省,R1,杭州市,R2,下沙经济开发区,R4,上沙路与华景街交叉口龙湖,RX
# 浙江,R1,杭州,R2,浙江省,R1,杭州市,R2,下沙经济开发区,R4,上沙路,R5,与,R99,华景街,R5,交叉口,R90,龙湖,R30
# 浙江,R1,杭州,R2,浙江省,R1,杭州市,R2,下沙经济开发区,R4,上沙路,R5,与,R99,华景街,R5,交叉口,R90,龙湖,R90
#
# 贵州省,R1,遵义市,R2,汇川区,R3,大连路遵医附院,RX
# 贵州省,R1,遵义市,R2,汇川区,R3,大连路,R5,遵医附院,R22
# 贵州省,R1,遵义市,R2,汇川区,R3,大连路遵医附院,R5
#
# 陕西省,R1,西安市,R2,未央区,R3,朱宏北路66号新福鑫纽约城农行朱宏路北段分理,RX
# 陕西省,R1,西安市,R2,未央区,R3,朱宏北路,R5,66号,R6,新福鑫纽约城农行朱宏路北段分理,R23
# 陕西省,R1,西安市,R2,未央区,R3,朱宏北路,R5,66号,R6,新福鑫纽约城农行朱宏路北段分理,R23
#
# 建行巴南支行保安部,RX,重庆市,R1,巴南区,R3,龙洲湾,R4,龙海大道5号,RX
# 建行巴南支行保安部重庆市巴南区龙洲湾,R23,龙海大道,R5,5号,R6
# 建行,R4,巴南支行保安部,R2,重庆市,R1,巴南区,R3,龙洲湾,R4,龙海大道,R5,5号,R6
#
# 内蒙古,R1,乌海市,R2,海勃湾区,R3,乌海市,R2,蒙西大白菜园区,RX
# 内蒙古,R1,乌海市,R2,海勃湾区,R3,乌海市,R2,蒙西大白菜园区,R31
# 内蒙古,R1,乌海市,R2,海勃湾区,R3,乌海市,R2,蒙西,R4,大白菜园区,R31
#
# 四川省,R1,成都市,R2,大邑县,R3,四川省,R1,大邑县,R3,青霞洞开13组,RX
# 四川省,R1,成都市,R2,大邑县,R3,四川省,R1,大邑县,R3,青霞洞开,R30,13组,R6
# 四川省,R1,成都市,R2,大邑县,R3,四川省,R1,大邑县,R3,青霞洞开,R30,13组,R6
#
# 广西壮族自治区,R1,河池市,R2,金城江区,R3,第二高级中学图音体组广西河池市,RX
# 广西壮族自治区,R1,河池市,R2,金城江区,R3,第二高级中学,R21,图音体组广西河池市,R6
# 广西壮族自治区,R1,河池市,R2,金城江区第二高级,R3,中学图音体组广西河池市,R30
#
# 陕西省,R1,榆林市,R2,靖边县,R3,小河镇,R4,政府靖边县小河镇政府,RX
# 陕西省,R1,榆林市,R2,靖边县,R3,小河镇,R4,政府靖边县小河镇政府,R24
# 陕西省,R1,榆林市,R2,靖边县,R3,小河镇政府,R4,靖边县,R3,小河镇政府,R24
#
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学无为县刘渡初级中学,RX
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学,R21,无为县刘渡初级中学,R21
# 安徽省,R1,芜湖市,R2,无为县,R3,刘渡镇,R4,刘渡初级中学无为县刘渡初级中学,R5
#
# 河北省,R1,承德市,R2,围场县,R3,大唤起乡,R4,政府大唤起乡人民政府,RX
# 河北省,R1,承德市,R2,围场县,R3,大唤起乡,R4,政府大唤起乡人民政府,R24
# 河北省,R1,承德市,R2,围场县,R3,大唤起乡,R4,政府,R24,大唤起乡人民政府,R24
#
# 安徽省,R1,淮南市,R2,寿县,R3,小甸镇,R4,人民政府寿县小甸镇人民政府,RX
# 安徽省,R1,淮南市,R2,寿县,R3,小甸镇,R4,人民政府寿县小甸镇人民政府,R24
# 安徽省,R1,淮南市,R2,寿县,R3,小甸镇,R4,人民政府,R4,寿县,R3,小甸镇人民政府,R24
#
# 河南省,R1,许昌县,R3,苏桥镇,R4,中许村小学许昌县苏桥镇中许小学,RX
# 河南省,R1,许昌县,R3,苏桥镇,R4,中许村小学,R21,许昌县苏桥镇中许小学,R21
# 河南省,R1,许昌县,R3,苏桥镇,R4,中许村小学,R21,许昌县苏桥镇中许小学,R3
#
# 河南省,R1,郑州市,R2,郑东,R3,新区,RX,商务外环五鼎大厦,RX
# 河南省,R1,郑州市,R2,郑东,R3,新区商务外环五鼎大厦,R31
# 河南省,R1,郑州市,R2,郑东新区,R3,商务外环五鼎大厦,R31
#
# 广东,R1,茂名,R2,广东省,R1,茂名市,R2,站前五路123号大院1一5号铺,RX
# 广东,R1,茂名,R2,广东省,R1,茂名市,R2,站前五路,R5,123号大院,R6,1一5号铺,R25
# 广东,R1,茂名,R2,广东省,R1,茂名市,R2,站前五路,R5,123号,R6,大院1一5号铺,R25
#
# 吉林省,R1,磐石市,R3,气象局,R4,吉林省,R1,磐石市气象局,RX
# 吉林省,R1,磐石市,R3,气象局,R4,吉林省,R1,磐石市气象局,R24
# 吉林省,R1,磐石市,R3,气象局,R4,吉林省,R1,磐石市,R24,气象局,R24
#
# 四川省,R1,广元市,R2,剑阁县,R3,龙江小学校剑阁县龙江小学校,RX
# 四川省,R1,广元市,R2,剑阁县,R3,龙江小学校,R21,剑阁县龙江小学校,R21
# 四川省,R1,广元市,R2,剑阁县龙江小学校,R21,剑阁县龙江小学校,R21
#
# 四川省,R1,广元市,R2,剑阁县,R3,下寺镇,R4,龙江小学校剑阁县龙江小学校,RX
# 四川省,R1,广元市,R2,剑阁县,R3,下寺镇,R4,龙江小学校,R21,剑阁县龙江小学校,R21
# 四川省,R1,广元市,R2,剑阁县,R3,下寺镇,R21,龙江小学校,R21,剑阁县龙江小学校,R21
#
# 永安镇国土资源所,R4
# 永安镇国土资源所,R4
# 永安镇国土资源所,R24
#
# 广东省,R1,茂名市,R2,信宜市,R3,怀乡镇,R4,第一中学信宜市怀乡第一中学,RX
# 广东省,R1,茂名市,R2,信宜市,R3,怀乡镇,R4,第一中学,R21,信宜市怀乡第一中学,R21
# 广东省,R1,茂名市,R2,信宜市,R3,怀乡镇,R21,第一中学信宜市怀乡第一中学,R21
#
# 重庆市,R1,重庆市,R1,永川,R3,双竹镇,R4,小学校重庆市利区双竹小学校,RX
# 重庆市,R1,重庆市,R1,永川,R3,双竹镇,R4,小学校重庆市利区双竹小学校,R21
# 重庆市,R1,重庆市,R1,永川,R3,双竹镇小学校重庆市利区双竹小学校,R21
#
# 陕西省,R1,咸阳市,R2,长武县,R3,巨家镇,R4,中心小学长武县巨家镇中心小学,RX
# 陕西省,R1,咸阳市,R2,长武县,R3,巨家镇,R4,中心小学,R21,长武县巨家镇中心小学,R21
# 陕西省,R1,咸阳市,R2,长武县,R3,巨家镇,R4,中心小学,R21,长武县巨家镇中心小学,R3
#
# 云南省,R1,玉溪市,R2,新平县,R3,戛洒镇,R4,小学,RX
# 云南省,R1,玉溪市,R2,新平县,R3,戛洒镇,R4,小学,R21
# 云南省,R1,玉溪市,R2,新平县,R3,戛洒镇,R4,小学,R5
#
# 山东省,R1,新泰市,R3,谷里镇,R4,初级中学,RX
# 山东省,R1,新泰市,R3,谷里镇,R4,初级中学,R21
# 山东省,R1,新泰市,R3,谷里镇初级中学,R21
#
# 云南省,R1,景洪,R3,东风小街中心小学景洪市小街中心小学,RX
# 云南省,R1,景洪,R3,东风小街,R5,中心小学景洪市小街中心小学,R21
# 云南省,R1,景洪,R5,东风小街中心小学,R5,景洪市小街中心小学,R21
# Exception ignored in: <function ScopedTFGraph.__del__ at 0x7f3114042160>
# Traceback (most recent call last):
#   File "/home/bangsun/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/c_api_util.py", line 53, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# 甘肃省,R1,武威市,R2,凉州区,R3,古浪县直滩初级中学,RX
# 甘肃省,R1,武威市,R2,凉州区,R3,古浪县直滩初级中学,R21
# 甘肃省,R1,武威市,R2,凉州区,R3,古浪县直滩初级中学,R21
#
# 北京,R1,朝阳区,R3,北京市,R1,朝阳区,R3,金盏乡,R4,小店村190号,RX
# 北京,R1,朝阳区,R3,北京市,R1,朝阳区,R3,金盏乡,R4,小店村,R5,190号,R6
# 北京,R1,朝阳区,R3,北京市,R1,朝阳区,R3,金盏乡,R4,小店村,R25,190号,R6
#
# 甘肃省,R1,庆阳市,R2,环县,R3,甘肃省,R1,第四中学,RX
# 甘肃省,R1,庆阳市,R2,环县,R3,甘肃省,R1,第四中学,R21
# 甘肃省,R1,庆阳市,R2,环县,R3,甘肃省第四中学,R21
#
# 广东省,R1,佛山市,R2,顺德区,R3,陈村镇,R4,碧桂花城碧湖豪庭10街21号,RX
# 广东省,R1,佛山市,R2,顺德区,R3,陈村镇,R4,碧桂花城,R5,碧湖豪庭,R30,10街,R5,21号,R6
# 广东省,R1,佛山市,R2,顺德区,R3,陈村镇,R4,碧桂花城碧湖豪庭10街,R30,21号,R6
#
# 天津市,R1,西青区,R3,杨柳青镇,R4,融盛新家居广场板材25号,RX
# 天津市,R1,西青区,R3,杨柳青镇,R4,融盛新家居广场板材,R31,25号,R6
# 天津市,R1,西青区,R3,杨柳青镇,R4,融盛新家居广场板材,R31,25号,R6
#
# 甘肃省,R1,陇南市,R2,西和县,R3,甘肃省,R1,西和县,R3,汉源镇,R4,凤居四小区刚泰27号楼西单元202室,RX
# 甘肃省,R1,陇南市,R2,西和县,R3,甘肃省,R1,西和县,R3,汉源镇,R4,凤居四小区,R30,刚泰,R30,27号楼,R6,西单元,R7,202室,R7
# 甘肃省,R1,陇南市,R2,西和县,R3,甘肃省,R1,西和县,R3,汉源镇,R4,凤居四小区刚泰,R30,27号楼,R6,西单元,R7,202室,R7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-93fa00513ea6> in <module>
# ----> 1 batchReadFiles('test4.txt')
#
# <ipython-input-10-62014d816fe4> in batchReadFiles(rdAddress)
#       3         for item in f:
#       4             address=list(item[:-1])
# ----> 5             M1 = tagger1.predict(address)
#       6             address1 = Process(address,M1)
#       7             M2 = predict(address)
#
# ~/anaconda3/lib/python3.8/site-packages/hanlp/components/taggers/rnn_tagger.py in predict(self, sents, batch_size, **kwargs)
#      45     def predict(self, sents: Union[List[str], List[List[str]]], batch_size=32, **kwargs) -> Union[
#      46         List[str], List[List[str]]]:
# ---> 47         return super().predict(sents, batch_size)
#      48
#      49     def save_weights(self, save_dir, filename='model.h5'):
#
# ~/anaconda3/lib/python3.8/site-packages/hanlp/common/component.py in predict(self, data, batch_size, **kwargs)
#     453         num_samples = 0
#     454         data_is_list = isinstance(data, list)
# --> 455         for idx, batch in enumerate(dataset):
#     456             samples_in_batch = tf.shape(batch[-1] if isinstance(batch[-1], tf.Tensor) else batch[-1][0])[0]
#     457             if data_is_list:
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     734
#     735   def __next__(self):  # For Python 3 compatibility
# --> 736     return self.next()
#     737
#     738   def _next_internal(self):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in next(self)
#     770   def next(self):
#     771     try:
# --> 772       return self._next_internal()
#     773     except errors.OutOfRangeError:
#     774       raise StopIteration
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     753         # and instead mimic ops placement in graphs: Operations on resource
#     754         # handles execute on the same device as where the resource is placed.
# --> 755         ret = gen_dataset_ops.iterator_get_next(
#     756             self._iterator_resource,
#     757             output_types=self._flat_output_types,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2602   if tld.is_eager:
#    2603     try:
# -> 2604       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2605         _ctx._context_handle, tld.device_name, "IteratorGetNext", name,
#    2606         tld.op_callbacks, iterator, "output_types", output_types,
#
# KeyboardInterrupt:
